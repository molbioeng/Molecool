# %%
import os
import pandas as pd
import numpy as np
from pyecg import ECGRecord

path = "/Users/jmargalef/Molecool/Code_HRV/Data" #Change the location of the file or folder.
files = sorted(os.listdir(path))
files.pop(0)
dataset = []
lead_names = ['ecg_0','ecg_1']

#Deleting the '2006' string to be able to read the data.
for file in files:
    if file.endswith('.hea'):
        for lead in lead_names:
            dataset.append(file + "/" + lead)
        fin = open("/Users/jmargalef/Molecool/Code_HRV/Data/" + file,"rt") #Change the location of the file or folder.
        data_file = fin.read()
        data_file = data_file.replace('2006','')
        data_file = data_file.replace('2007','')
        data_file = data_file.replace('2008','')
        fin = open("/Users/jmargalef/Molecool/Code_HRV/Data/" + file,"wt") #Change the location of the file or folder.
        fin.write(data_file)
        fin.close()

database_ecg = pd.DataFrame (columns = dataset)

for file in files:
    #Reading and storing the data into a dataframe.
    hea_path = "/Users/jmargalef/Molecool/Code_HRV/Data/" + file #Change the location of the file or folder.
    record = ECGRecord.from_wfdb(hea_path)
    for lead in lead_names:
        time = record.time
        signal = record.get_lead(lead)
        database_ecg[file + "/" + lead] = pd.Series(signal)
# Out:
#          S0250ECG.hea/ecg_0  S0250ECG.hea/ecg_1  S0256ECG.hea/ecg_0  \
# 0                     -88.0              -483.0                21.0
# 1                     -93.0              -496.0                21.0
# 2                     -99.0              -509.0                20.0
# 3                    -104.0              -520.0                21.0
# 4                    -110.0              -533.0                19.0
# ...                     ...                 ...                 ...
# 1256371               340.0              -123.0               -21.0
# 1256372               367.0              -151.0               -21.0
# 1256373               388.0              -177.0               -20.0
# 1256374               405.0              -201.0               -20.0
# 1256375               421.0              -232.0               -21.0
#
#          S0256ECG.hea/ecg_1  S0273ECG.hea/ecg_0  S0273ECG.hea/ecg_1  \
# 0                    -130.0                0.07                0.19
# 1                    -123.0                0.07                0.15
# 2                    -114.0                0.06                0.12
# 3                    -102.0                0.03                0.18
# 4                     -92.0               -0.01                0.27
# ...                     ...                 ...                 ...
# 1256371              -107.0                0.23                0.13
# 1256372              -112.0                0.25                0.00
# 1256373              -113.0                0.28               -0.18
# 1256374              -114.0                0.27               -0.27
# 1256375              -116.0                0.23               -0.26
#
#          S0282ECG.hea/ecg_0  S0282ECG.hea/ecg_1  S0424ECG.hea/ecg_0  \
# 0                    -138.0              -119.0                10.0
# 1                    -141.0              -130.0                10.0
# 2                    -143.0              -141.0                12.0
# 3                    -147.0              -153.0                13.0
# 4                    -149.0              -164.0                12.0
# ...                     ...                 ...                 ...
# 1256371                 NaN                 NaN                 NaN
# 1256372                 NaN                 NaN                 NaN
# 1256373                 NaN                 NaN                 NaN
# 1256374                 NaN                 NaN                 NaN
# 1256375                 NaN                 NaN                 NaN
#
#          S0424ECG.hea/ecg_1  S0250ECG.dat/ecg_0  S0250ECG.dat/ecg_1  \
# 0                     -98.0               -88.0              -483.0
# 1                     -98.0               -93.0              -496.0
# 2                     -98.0               -99.0              -509.0
# 3                     -96.0              -104.0              -520.0
# 4                     -95.0              -110.0              -533.0
# ...                     ...                 ...                 ...
# 1256371                 NaN               340.0              -123.0
# 1256372                 NaN               367.0              -151.0
# 1256373                 NaN               388.0              -177.0
# 1256374                 NaN               405.0              -201.0
# 1256375                 NaN               421.0              -232.0
#
#          S0256ECG.dat/ecg_0  S0256ECG.dat/ecg_1  S0273ECG.dat/ecg_0  \
# 0                      21.0              -130.0                0.07
# 1                      21.0              -123.0                0.07
# 2                      20.0              -114.0                0.06
# 3                      21.0              -102.0                0.03
# 4                      19.0               -92.0               -0.01
# ...                     ...                 ...                 ...
# 1256371               -21.0              -107.0                0.23
# 1256372               -21.0              -112.0                0.25
# 1256373               -20.0              -113.0                0.28
# 1256374               -20.0              -114.0                0.27
# 1256375               -21.0              -116.0                0.23
#
#          S0273ECG.dat/ecg_1  S0282ECG.dat/ecg_0  S0282ECG.dat/ecg_1  \
# 0                      0.19              -138.0              -119.0
# 1                      0.15              -141.0              -130.0
# 2                      0.12              -143.0              -141.0
# 3                      0.18              -147.0              -153.0
# 4                      0.27              -149.0              -164.0
# ...                     ...                 ...                 ...
# 1256371                0.13                 NaN                 NaN
# 1256372                0.00                 NaN                 NaN
# 1256373               -0.18                 NaN                 NaN
# 1256374               -0.27                 NaN                 NaN
# 1256375               -0.26                 NaN                 NaN
#
#          S0424ECG.dat/ecg_0  S0424ECG.dat/ecg_1
# 0                      10.0               -98.0
# 1                      10.0               -98.0
# 2                      12.0               -98.0
# 3                      13.0               -96.0
# 4                      12.0               -95.0
# ...                     ...                 ...
# 1256371                 NaN                 NaN
# 1256372                 NaN                 NaN
# 1256373                 NaN                 NaN
# 1256374                 NaN                 NaN
# 1256375                 NaN                 NaN
#
# [1256376 rows x 20 columns]
