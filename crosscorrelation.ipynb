# %%
# Importing packages
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data description for only patients with associated ECG values
df_ECG = pd.read_csv('./database/data_description/ECG_data_summary_table.csv', encoding = 'latin-1')
df_ECG.set_index('patient ID', inplace=True)

# Data description for all patients
df_all = pd.read_csv('./database/data_description/GE-75_data_summary_table.csv', encoding = 'latin-1')
df_all.set_index('patient ID', inplace=True)

# %%
# NOT NECESSARY TO RUN, ONLY RUN THIS ONCE, HARD CODED TO JUST REMOVE ALL COLUMNS WITHIN THAT INDEX
# The variables we want to focus on:
df_all.drop(df_all.iloc[:,12:937], inplace = True, axis = 1) #drops all of the brain perfusion variables
df_all.drop(df_all.iloc[:,-69:], inplace = True, axis = 1) #drops all of the MENTAL test variables
df_ECG.drop(df_ECG.iloc[:,12:937], inplace = True, axis = 1) #drops all of the brain perfusion variables
df_ECG.drop(df_ECG.iloc[:,-69:], inplace = True, axis = 1) #drops all of the MENTAL test variables

# Strip columns with all NaN values
df_all = df_all.dropna(axis='columns', how='all')
df_ECG = df_all.dropna(axis='columns', how='all')

# %%
# easy way to check the variables present in the database
# Out:
# patient ID
# S0250     7.0
# S0254     0.0
# S0255     3.0
# S0256    23.0
# s0257     0.0
#          ...
# S0435     NaN
# s0437     NaN
# s0438     NaN
# s0441     NaN
# s0443     NaN
# Name: Diabetes Duration, Length: 88, dtype: float64

# %%
# Select variables you want to make a cross-correlation matrix out of
neuropathy = ['Group', 'Diabetes Duration', 'age', 'WBC K/uL', 'RBC m/uL', 'Hgb g/dL', 'GLUCOSE mg/dL','Hb A1C%', 'Dizziness AUTONOMIC SYMPTOMS', 'LDL CALCmg/dL','HDL mg/dL', 'Neuropathy AUTONOMIC SYMPTOMS']
retinopathy = ['Group', 'Diabetes Duration','age','BMI', 'Hb A1C%', 'CRP (mg/L)', 'URINE ALBUMIN mg/dL', 'Hgb g/dL', 'Retinopathy Grading']
general = ['Group', 'Diabetes Duration','age','BMI','Hb A1C%','CRP (mg/L)','Neuropathy AUTONOMIC SYMPTOMS','WBC K/uL','RBC m/uL','Hgb g/dL','GLUCOSE mg/dL','URINE CREAT mg/dL','URINE ALBUMIN mg/dL', 'CHOLESTmg/dL','LDL CALCmg/dL','Retinopathy Grading']
df_all[general].head()
# Out:
#               Group  Diabetes Duration  age        BMI  Hb A1C%  CRP (mg/L)  \
# patient ID
# S0250            DM                7.0   50  35.782279      9.4       0.240
# S0254       CONTROL                0.0   69  24.275148      5.1       0.104
# S0255            DM                3.0   78  28.466932      NaN         NaN
# S0256            DM               23.0   65  29.629630      7.1       0.060
# s0257       CONTROL                0.0   55  24.328720      NaN         NaN
#
#            Neuropathy AUTONOMIC SYMPTOMS  WBC K/uL  RBC m/uL  Hgb g/dL  \
# patient ID
# S0250                                 NO       6.9      5.31      15.0
# S0254                                 NO       6.7      4.50      14.2
# S0255                                 No       NaN       NaN       NaN
# S0256                                 NO       4.4      3.58      10.3
# s0257                                 No       NaN       NaN       NaN
#
#             GLUCOSE mg/dL  URINE CREAT mg/dL  URINE ALBUMIN mg/dL  \
# patient ID
# S0250               211.0               65.0                  2.4
# S0254                95.0              137.0                  8.0
# S0255                 NaN                NaN                  NaN
# S0256               111.0               69.0                  0.3
# s0257                 NaN                NaN                  NaN
#
#             CHOLESTmg/dL  LDL CALCmg/dL  Retinopathy Grading
# patient ID
# S0250              135.0           72.0                  NaN
# S0254              176.0           98.0                  0.0
# S0255                NaN            NaN                  NaN
# S0256              194.0           97.0                  0.0
# s0257                NaN            NaN                  NaN

# %%
# Unfortunately .corr() ignores all columns with all non-numeric values so find a way to represent these (is just converting to binary 1 or 0 enough?)
df_all[neuropathy] = df_all[neuropathy].apply(lambda x: x.astype(str).str.lower()) # Converts all of the values to string, and all strings to lowercase
df_all[retinopathy] = df_all[retinopathy].apply(lambda x: x.astype(str).str.lower()) # Converts all of the values to string, and all strings to lowercase
df_all[general] = df_all[general].apply(lambda x: x.astype(str).str.lower()) # Converts all of the values to string, and all strings to lowercase
df_all['Dizziness AUTONOMIC SYMPTOMS'].replace(('yes', 'no'), (1, 0), inplace=True)
df_all['Neuropathy AUTONOMIC SYMPTOMS'].replace(('yes', 'no'), (1, 0), inplace=True)
df_all['Group'].replace(('dm', 'control'), (1, 0), inplace=True)
df_all[neuropathy] = df_all[neuropathy].apply(lambda x: x.astype(float))
df_all[retinopathy] = df_all[retinopathy].apply(lambda x: x.astype(float))
df_all[general] = df_all[general].apply(lambda x: x.astype(float))

# %%
corr=df_all[neuropathy].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_e2b8d_row0_col0, #T_e2b8d_row1_col1, #T_e2b8d_row2_col2, #T_e2b8d_row3_col3, #T_e2b8d_row4_col4, #T_e2b8d_row5_col5, #T_e2b8d_row6_col6, #T_e2b8d_row7_col7, #T_e2b8d_row8_col8, #T_e2b8d_row9_col9, #T_e2b8d_row10_col10, #T_e2b8d_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e2b8d_row0_col1, #T_e2b8d_row9_col10 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_e2b8d_row0_col2, #T_e2b8d_row0_col4 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_e2b8d_row0_col3, #T_e2b8d_row4_col7 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_e2b8d_row0_col5, #T_e2b8d_row1_col2, #T_e2b8d_row1_col4 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_e2b8d_row0_col6, #T_e2b8d_row11_col0 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_e2b8d_row0_col7 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_e2b8d_row0_col8, #T_e2b8d_row5_col6 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_e2b8d_row0_col9, #T_e2b8d_row2_col7, #T_e2b8d_row4_col2, #T_e2b8d_row4_col8, #T_e2b8d_row5_col1, #T_e2b8d_row5_col10, #T_e2b8d_row9_col0, #T_e2b8d_row9_col6, #T_e2b8d_row9_col8, #T_e2b8d_row9_col11, #T_e2b8d_row10_col3, #T_e2b8d_row10_col4, #T_e2b8d_row10_col5, #T_e2b8d_row10_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e2b8d_row0_col10, #T_e2b8d_row2_col1, #T_e2b8d_row7_col3, #T_e2b8d_row7_col5 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_e2b8d_row0_col11, #T_e2b8d_row3_col6, #T_e2b8d_row4_col6 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_e2b8d_row1_col0 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_e2b8d_row1_col3 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_e2b8d_row1_col5, #T_e2b8d_row8_col7 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_e2b8d_row1_col6, #T_e2b8d_row4_col9 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_e2b8d_row1_col7 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_e2b8d_row1_col8 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_e2b8d_row1_col9, #T_e2b8d_row4_col0, #T_e2b8d_row8_col10, #T_e2b8d_row11_col5 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_e2b8d_row1_col10 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_e2b8d_row1_col11 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_e2b8d_row2_col0, #T_e2b8d_row7_col4, #T_e2b8d_row8_col1 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_e2b8d_row2_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_e2b8d_row2_col4, #T_e2b8d_row7_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_e2b8d_row2_col5 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_e2b8d_row2_col6 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_e2b8d_row2_col8, #T_e2b8d_row5_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_e2b8d_row2_col9, #T_e2b8d_row11_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_e2b8d_row2_col10, #T_e2b8d_row6_col1 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_e2b8d_row2_col11 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_e2b8d_row3_col0, #T_e2b8d_row8_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_e2b8d_row3_col1 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_e2b8d_row3_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_e2b8d_row3_col4 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_e2b8d_row3_col5 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_e2b8d_row3_col7, #T_e2b8d_row7_col9, #T_e2b8d_row10_col11 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_e2b8d_row3_col8 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_e2b8d_row3_col9, #T_e2b8d_row5_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_e2b8d_row3_col10, #T_e2b8d_row8_col11 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_e2b8d_row3_col11 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_e2b8d_row4_col1, #T_e2b8d_row10_col1 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_e2b8d_row4_col3 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_e2b8d_row4_col5 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_e2b8d_row4_col10 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_e2b8d_row4_col11 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_e2b8d_row5_col3 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_e2b8d_row5_col4 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_e2b8d_row5_col7 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_e2b8d_row5_col8 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_e2b8d_row5_col9 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_e2b8d_row5_col11 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_e2b8d_row6_col0 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_e2b8d_row6_col2, #T_e2b8d_row8_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_e2b8d_row6_col3 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_e2b8d_row6_col4 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_e2b8d_row6_col5 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_e2b8d_row6_col7 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_e2b8d_row6_col8 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_e2b8d_row6_col9, #T_e2b8d_row9_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_e2b8d_row6_col10 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_e2b8d_row6_col11 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_e2b8d_row7_col0 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_e2b8d_row7_col1 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_e2b8d_row7_col6 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_e2b8d_row7_col8 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_e2b8d_row7_col10 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_e2b8d_row7_col11 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_e2b8d_row8_col3, #T_e2b8d_row8_col9 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_e2b8d_row8_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_e2b8d_row8_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_e2b8d_row8_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_e2b8d_row9_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_e2b8d_row9_col3 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_e2b8d_row9_col4 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_e2b8d_row9_col5 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_e2b8d_row9_col7 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_e2b8d_row10_col0, #T_e2b8d_row11_col4, #T_e2b8d_row11_col9 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_e2b8d_row10_col2, #T_e2b8d_row11_col8 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_e2b8d_row10_col7 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_e2b8d_row10_col8, #T_e2b8d_row11_col7 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_e2b8d_row10_col9 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_e2b8d_row11_col1 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_e2b8d_row11_col2 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_e2b8d_row11_col6 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_e2b8d_row11_col10 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# </style>
# <table id="T_e2b8d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Group</th>
#       <th class="col_heading level0 col1" >Diabetes Duration</th>
#       <th class="col_heading level0 col2" >age</th>
#       <th class="col_heading level0 col3" >WBC K/uL</th>
#       <th class="col_heading level0 col4" >RBC m/uL</th>
#       <th class="col_heading level0 col5" >Hgb g/dL</th>
#       <th class="col_heading level0 col6" >GLUCOSE mg/dL</th>
#       <th class="col_heading level0 col7" >Hb A1C%</th>
#       <th class="col_heading level0 col8" >Dizziness AUTONOMIC SYMPTOMS</th>
#       <th class="col_heading level0 col9" >LDL CALCmg/dL</th>
#       <th class="col_heading level0 col10" >HDL mg/dL</th>
#       <th class="col_heading level0 col11" >Neuropathy AUTONOMIC SYMPTOMS</th>
#     </tr>
#   </th

# %%
corr=df_all[retinopathy].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_202b8_row0_col0, #T_202b8_row1_col1, #T_202b8_row2_col2, #T_202b8_row3_col3, #T_202b8_row4_col4, #T_202b8_row5_col5, #T_202b8_row6_col6, #T_202b8_row7_col7, #T_202b8_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_202b8_row0_col1, #T_202b8_row5_col3 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_202b8_row0_col2, #T_202b8_row1_col3, #T_202b8_row5_col2 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_202b8_row0_col3 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_202b8_row0_col4 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_202b8_row0_col5 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_202b8_row0_col6 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_202b8_row0_col7, #T_202b8_row5_col8 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_202b8_row0_col8 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_202b8_row1_col0 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_202b8_row1_col2 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_202b8_row1_col4, #T_202b8_row8_col3 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_202b8_row1_col5 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_202b8_row1_col6 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_202b8_row1_col7 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_202b8_row1_col8 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_202b8_row2_col0, #T_202b8_row5_col4 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_202b8_row2_col1 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_202b8_row2_col3, #T_202b8_row2_col4, #T_202b8_row3_col2, #T_202b8_row5_col6, #T_202b8_row7_col0, #T_202b8_row7_col1, #T_202b8_row7_col8, #T_202b8_row8_col5, #T_202b8_row8_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_202b8_row2_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_202b8_row2_col6, #T_202b8_row3_col6, #T_202b8_row4_col6, #T_202b8_row4_col7 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_202b8_row2_col7 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_202b8_row2_col8 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_202b8_row3_col0 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_202b8_row3_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_202b8_row3_col4 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_202b8_row3_col5 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_202b8_row3_col7, #T_202b8_row8_col6 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_202b8_row3_col8 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_202b8_row4_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_202b8_row4_col1 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_202b8_row4_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_202b8_row4_col3 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_202b8_row4_col5 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_202b8_row4_col8 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_202b8_row5_col0 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_202b8_row5_col1 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_202b8_row5_col7 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_202b8_row6_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_202b8_row6_col1, #T_202b8_row8_col4 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_202b8_row6_col2, #T_202b8_row6_col3 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_202b8_row6_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_202b8_row6_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_202b8_row6_col7 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_202b8_row6_col8 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_202b8_row7_col2, #T_202b8_row8_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_202b8_row7_col3 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_202b8_row7_col4 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_202b8_row7_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_202b8_row7_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_202b8_row8_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_202b8_row8_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# </style>
# <table id="T_202b8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Group</th>
#       <th class="col_heading level0 col1" >Diabetes Duration</th>
#       <th class="col_heading level0 col2" >age</th>
#       <th class="col_heading level0 col3" >BMI</th>
#       <th class="col_heading level0 col4" >Hb A1C%</th>
#       <th class="col_heading level0 col5" >CRP (mg/L)</th>
#       <th class="col_heading level0 col6" >URINE ALBUMIN mg/dL</th>
#       <th class="col_heading level0 col7" >Hgb g/dL</th>
#       <th class="col_heading level0 col8" >Retinopathy Grading</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_202b8_level0_row0" class="row_heading level0 row0" >Group</th>
#       <td id="T_202b8_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_202b8_row0_col1" class="data row0 col1" >0.343247</td>
#       <td id="T_202b8_row0_col2" class="data row0 col2" >0.017992</td>
#       <td id="T_202b8_row0_col3" class="data row0 col3" >0.289253</td>
#       <td id="T_202b8_row0_col4" class="data row0 col4" >0.396138</td>
#       <td id="T_202b8_row0_col5" class="data row0 col5" >0.100444</td>
#       <td id="T_202b8_row0_col6" class="data row0 col6" >0.006906</td>
#       <td id="T_202b8_row0_col7" class="data row0 col7" >-0.083338</td>
#       <td id="T_202b8_row0_col8" class="data row0 col8" >0.091844</td>
#     </tr>
#     <tr>
#       <th id="T_202b8_level0_row1" class="row_heading level0 row1" >Diabetes Duration</th>
#       <td id="T_202b8_row1_col0" class="data row1 col0" >0.343247</td>
#       <td id="T_202b8_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_202b8_row1_col2" class="data row1 col2" >0.061253</td>
#       <td id="T_202b8_row1_col3" class="data row1 col3" >0.016606</td>
#       <td id="T_202b8_row1_col4" class="data row1 col4" >0.355991</td>
#       <td id="T_202b8_row1_col5" class="data row1 col5" >0.020845</td>
#       <td id="T_202b8_row1_col6" class="data row1 col6" >0.105035</td>
#       <td id="T_202b8_row1_col7" class="data row1 col7" >-0.147769</td>
#       <td id="T_202b8_row1_col8" class="data row1 col8" >0.286347</td>
#     </tr>
#     <tr>
#       <th id="T_202b8_level0_row2" class="row_heading level0 row2" >age</th>
#       <td id="T_202b8_row2_col0" class="data row2 col0" >0.017992</td>
#       <td id="T_202b8_row2_col1" class="data row2 col1" >0.061253</td>
#       <td id="T_202b8_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_202b8_row2_col3" class="data row2 col3" >-0.333250</td>
#       <td id="T_202b8_row2_col4" class="data row2 col4" >-0.176768</td>
#       <td id="T_202b8_row2_col5" class="data row2 col5" >0.017296</td>
#       <td id="T_202b8_row2_col6" class="data row2 col6" >0.042426</td>
#       <td id="T_202b8_row2_col7" class="data row2 col7" >-0.160087</td>
#       <td id="T_202b8_row2_col8" class="data row2 col8" >-0.159104</td>
#     </tr>
#     <tr>
#       <th id="T_202b8_level0_row3" class="row_heading level0 row3" >BMI</th>
#       <td id="T_202b8_row3_col0" class="data row3 col0" >0.289253</td>
#       <td id="T_202b8_row3_col1" class="data row3 col1" >0.016606</td>
#       <td id="T_202b8_row3_col2" class="data row3 col2" >-0.333250</td>
#       <td id="T_202b8_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_202b8_row3_col4" class="data row3 col4" >0.241591</td>
#       <td id="T_202b8_row3_col5" class="data row3 col5" >0.236338</td>
#       <td id="T_202b8_row3_col6" class="data row3 col6" >0.043067</td>
#       <td id="T_202b8_row3_col7" class="data row3 col7" >-0.009650</td>
#       <td id="T_202b8_row3_col8" class="data row3 col8" >0.268364</td>
#     </tr>
#     <tr>
#       <th id="T_202b8_level0_row4" class="row_heading level0 row4" >Hb A1C%</th>
#       <td id="T_202b8_row4_col0" class="data

# %%
corr=df_all[general].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_21527_row0_col0, #T_21527_row1_col1, #T_21527_row2_col2, #T_21527_row3_col3, #T_21527_row4_col4, #T_21527_row5_col5, #T_21527_row6_col6, #T_21527_row7_col7, #T_21527_row8_col8, #T_21527_row9_col9, #T_21527_row10_col10, #T_21527_row11_col11, #T_21527_row12_col12, #T_21527_row13_col13, #T_21527_row14_col14, #T_21527_row15_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_21527_row0_col1, #T_21527_row5_col3, #T_21527_row7_col3 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_21527_row0_col2, #T_21527_row1_col3, #T_21527_row1_col14, #T_21527_row5_col2, #T_21527_row8_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_21527_row0_col3 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_21527_row0_col4 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_21527_row0_col5, #T_21527_row1_col12 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_21527_row0_col6, #T_21527_row4_col15, #T_21527_row5_col14, #T_21527_row12_col8 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_21527_row0_col7, #T_21527_row14_col11, #T_21527_row15_col12 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_21527_row0_col8, #T_21527_row6_col9, #T_21527_row7_col13 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_21527_row0_col9, #T_21527_row3_col13, #T_21527_row4_col11, #T_21527_row9_col12, #T_21527_row14_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_21527_row0_col10, #T_21527_row6_col15, #T_21527_row7_col9 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_21527_row0_col11, #T_21527_row3_col1, #T_21527_row10_col14 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_21527_row0_col12, #T_21527_row8_col2, #T_21527_row8_col5, #T_21527_row10_col13 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_21527_row0_col13, #T_21527_row0_col14, #T_21527_row2_col3, #T_21527_row2_col4, #T_21527_row2_col7, #T_21527_row2_col8, #T_21527_row3_col2, #T_21527_row8_col11, #T_21527_row9_col1, #T_21527_row13_col10, #T_21527_row13_col12, #T_21527_row13_col15, #T_21527_row14_col0, #T_21527_row14_col6, #T_21527_row15_col5, #T_21527_row15_col9, #T_21527_row15_col11 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_21527_row0_col15 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_21527_row1_col0 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_21527_row1_col2, #T_21527_row2_col0, #T_21527_row8_col3 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_21527_row1_col4, #T_21527_row15_col3 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_21527_row1_col5, #T_21527_row9_col6, #T_21527_row11_col8 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_21527_row1_col6, #T_21527_row11_col13, #T_21527_row15_col6 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_21527_row1_col7, #T_21527_row5_col10, #T_21527_row7_col1, #T_21527_row15_col7 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_21527_row1_col8, #T_21527_row3_col6, #T_21527_row4_col13 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_21527_row1_col9, #T_21527_row14_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_21527_row1_col10, #T_21527_row1_col11 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_21527_row1_col13, #T_21527_row12_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_21527_row1_col15 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_21527_row2_col1, #T_21527_row11_col4, #T_21527_row11_col5, #T_21527_row11_col10, #T_21527_row13_col1 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_21527_row2_col5, #T_21527_row11_col12 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_21527_row2_col6, #T_21527_row3_col4, #T_21527_row9_col7 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_21527_row2_col9 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_21527_row2_col10, #T_21527_row2_col11, #T_21527_row12_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_21527_row2_col12, #T_21527_row3_col12, #T_21527_row4_col2, #T_21527_row4_col6, #T_21527_row4_col12, #T_21527_row11_col9 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_21527_row2_col13, #T_21527_row3_col8, #T_21527_row12_col9 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_21527_row2_col14, #T_21527_row8_col13, #T_21527_row12_col14 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_21527_row2_col15, #T_21527_row8_col15 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_21527_row3_col0 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_21527_row3_col5 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_21527_row3_col7, #T_21527_row8_col14, #T_21527_row12_col15 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_21527_row3_col9, #T_21527_row5_col8, #T_21527_row8_col12, #T_21527_row10_col12 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_21527_row3_col10 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_21527_row3_col11, #T_21527_row7_col6, #T_21527_row9_col3, #T_21527_row10_col7, #T_21527_row11_col6, #T_21527_row13_col2 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_21527_row3_col14 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_21527_row3_col15 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_21527_row4_col0 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_21527_row4_col1 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_21527_row4_col3 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_21527_row4_col5 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_21527_row4_col7, #T_21527_row6_col14 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_21527_row4_col8, #T_21527_row9_col10, #T_21527_row12_col10 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_21527_row4_col9 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_21527_row4_col10 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_21527_row4_col14, #T_21527_row5_col11, #T_21527_row7_col4, #T_21527_row7_col15 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_21527_row5_col0 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_21527_row5_col1, #T_21527_row5_col6, #T_21527_row10_col2 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_21527_row5_col4, #T_21527_row6_col5 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_21527_row5_col7, #T_21527_row11_col15 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_21527_row5_col9, #T_21527_row6_col7, #T_21527_row14_col8 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_21527_row5_col12, #T_21527_row13_col0, #T_21527_row14_col7, #T_21527_row15_col8 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_21527_row5_col13 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_21527_row5_col15, #T_21527_row6_col8, #T_21527_row7_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_21527_row6_col0 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_21527_row6_col1, #T_21527_row15_col0 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_21527_row6_col2 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_21527_row6_col3, #T_21527_row10_col1 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_21527_row6_col4, #T_21527_row9_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_21527_row6_col10 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_21527_row6_col11 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_21527_row6_col12, #T_21527_row12_col13 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_21527_row6_col13, #T_21527_row8_col1, #T_21527_row13_col9 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_21527_row7_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_21527_row7_col5 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_21527_row7_col8 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_21527_row7_col10, #T_21527_row8_col10, #T_21527_row10_col9, #T_21527_row12_col2, #T_21527_row12_col3 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_21527_row7_col11, #T_21527_row12_col4, #T_21527_row13_col8 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_21527_row7_col12, #T_21527_row10_col15 {
#   background-color: #a9c6fd;
#   color:
