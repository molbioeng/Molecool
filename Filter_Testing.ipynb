# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Notebook to test out filters
# Use this notebook to gain an intuition of how the filters we're applying work and test if we're applying them correctly...
#
# ## The Signals
# ### Unit Step

# %%
#Heavyside step function
x_vals = np.arange(-100,100,0.1)
step = np.heaviside(x_vals, 1)
plt.plot(x_vals, step)

# %% [markdown]
# ### Sinewave

# %%
sine = np.sin(x_vals)
plt.plot(sine)

# %% [markdown]
# ### Synthetic ECG signal
# Understanding for the Synthetic ECG signal came from: http://web.mit.edu/~gari/www/papers/ieeetbe50p289.pdf

# %%
#Parameters for ECG signal

# %%
#ODEs involved in the model

# %%
#Integration of ODES

#Introducing baseline wander

# %%
#Vary angular frequency to vary R-R interval change

# %%
#Inducing effects of RSA and Mayer waves

# %%
#Adding white noise

# %% [markdown]
# ## Butterworth Filter
